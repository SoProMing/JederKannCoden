# %% [markdown]
# [Jeder kann coden](../../abstract/Contents.de.ipynb) / [Programmieren & TicTacToe](../../Programming_And_TicTacToe.de.ipynb) / [C# Einführung](../CSharp_Introduction.de.ipynb)
#
# # Programmieren im Softwareentwicklungsprozess
#
# <table border="0">
#   <tr>
#     <td>
#         <img src="Software_Product_Mastering Medium.jpeg">
#     </td>
#     <td rowspan="2">
#         <a href="https://miro.com/app/board/o9J_lOJi2o0=/?moveToWidget=3458764554347680798&cot=14"><img src="Radar_Programming_n_SoProMing.jpg"></a>
#     </td>
#   </tr>
#   <tr>
#     <td>
#       <a href="https://martinfowler.com/articles/agileCulture.html" target="_blank">Agile Culture – Martin Fowler</a><br>
#       <a href="https://www.atlassian.com/continuous-delivery/principles/continuous-integration" target="_blank">Continuous Integration – Atlassian Guide</a><br>
#       <a href="https://12factor.net/" target="_blank">The Twelve-Factor App – Best Practices for Modern Apps</a><br>
#       <a href="https://www.mountaingoatsoftware.com/agile/scrum/roles" target="_blank">Scrum Rollen erklärt – Mountain Goat Software</a><br>
#       <a href="https://clean-code-developer.de/" target="_blank">Clean Code Developer – Deutschsprachige Initiative</a><br>
#       <a href="https://devops.com/" target="_blank">DevOps.com – News und Hintergrundberichte</a><br>
#       <a href="https://docs.microsoft.com/en-us/azure/devops/learn/what-is-devops" target="_blank">Was ist DevOps? – Microsoft Docs</a><br>
#       <a href="https://www.thoughtworks.com/radar" target="_blank">Technology Radar – ThoughtWorks</a><br>
#       <a href="https://dannorth.net/introducing-bdd/" target="_blank">Introducing BDD – Dan North</a><br>
#       <a href="https://hexagonal.dev/" target="_blank">Hexagonal Architecture – Ports & Adapters erklärt</a><br>
#       <a href="https://domaindrivendesign.org/" target="_blank">Domain-Driven Design Community</a><br>
#       <a href="https://www.infoq.com/devops/" target="_blank">DevOps Artikel und Trends – InfoQ</a><br>
#       <a href="https://www.leadingagile.com/blog/2015/04/four-quadrants-of-testing/" target="_blank">Test Quadrants – Agile Testing Framework</a><br>
#       <a href="https://basecamp.com/shapeup" target="_blank">Shape Up – Produktentwicklung bei Basecamp</a><br>
#       <a href="https://rework.withgoogle.com/" target="_blank">re:Work – Google’s Guide zu Team-Kultur und Psychologischer Sicherheit</a><br>
#     </td>
#   </tr>
# </table>
#
# <a href="https://miro.com/app/board/uXjVLKHGo6E=/?moveToWidget=3458764605541796363&cot=14"><img src="SoProMing.jpg" style="width:100%;"></a>
#
# Der Begriff **Software Product Mastering** wird von mir verwendet, um deutlich zu machen, dass es bei der erfolgreichen Entwicklung und dem Betrieb von Softwareprodukten um weit mehr geht als um etablierte Konzepte wie *DevOps-Kultur*, *Agile Development*, *SOLID-Prinzipien* oder *Clean Code*. Diese Bausteine sind wichtig – doch *Mastering* bedeutet, sie **kontextsensibel, iterativ und produktorientiert** zu vereinen. Es ist ein ganzheitlicher Ansatz, der **Kultur, Praktiken und Technologie** gleichermaßen berücksichtigt – mit dem Ziel, Produkte nicht nur zu bauen, sondern sie als lebendige Systeme **zu verstehen, weiterzuentwickeln und in ihrem Kontext zu meistern**.
#
# > Mehr zum Thema Software Product Mastering (SoProMing) findest du auf der <a href="https://www8.2hands.de/🚀-software-product-mastering/">https://www8.2hands.de/🚀-software-product-mastering/</a>.

# %% [markdown]
# ## Programmieren – Nur ein Puzzleteil im Softwareentwicklungsprozess
#
# **Ein Überblick mit Fokus auf Software Product Mastering**
#
# ### Einleitung
#
# Viele verbinden Softwareentwicklung primär mit **Programmieren** – also dem Schreiben von Quellcode. Doch moderne Softwareentwicklung umfasst weit mehr: sie ist ein **interdisziplinärer Prozess**, in dem Kommunikation, Struktur, Prozesse und Technologie zusammenspielen.
#
# Der Ansatz **Software Product Mastering** betrachtet genau dieses Zusammenspiel. Er erkennt Programmieren als wichtigen, aber eingebetteten Aspekt in einem holistischen Produktentwicklungsprozess, der von **Kultur, Praktiken und Technologie** getragen wird.
#
# ### Anforderungsanalyse & Nutzerfokus
#
# Bevor überhaupt Code entsteht, müssen Anforderungen verstanden und geschärft werden. Hier geht es um:
#
# * **Nutzerbedürfnisse erkennen**
# * **Geschäftsziele klären**
# * **Rahmenbedingungen verstehen**
#
# 🚀 **Software Product Mastering Bezug:**
# Wir nutzen hier Prinzipien wie **Empathy Driven Design** und binden Engineers früh in Interviews, Shadowing oder Produktstrategie ein. Anforderungen entstehen im Dialog – nicht im Elfenbeinturm.
#
# ### Architektur & Design
#
# Welche Komponenten gibt es? Wie kommunizieren sie? Was ist langfristig wartbar? Architekturentscheidungen sind entscheidend für die Nachhaltigkeit von Software.
#
# 🚀 **Software Product Mastering Bezug:**
# Architektur wird bei uns **iterativ und experimentell** gedacht. MVPs und Spikes sind erlaubt. Wir folgen dem Prinzip: *„Just enough architecture“* und setzen auf **Inspect & Adapt** statt auf große Wurfpläne.
#
# ### Programmieren – Das Handwerk
#
# Hier entsteht der ausführbare Code. Es geht um:
#
# * Lesbarkeit, Wartbarkeit, Effizienz
# * Testbarkeit, Wiederverwendbarkeit
# * Dokumentation und Namensgebung
#
# 🚀 **Software Product Mastering Bezug:**
# Wir verstehen Programmieren als Teil der **geteilten Verantwortung im Team**. Code entsteht oft gemeinsam (Pair/Mob), wird automatisiert überprüft und in einem **Produktverständnis-Kontext** entwickelt. Wir bevorzugen **Domain-Driven Design** und setzen auf eine lebendige Code-Kultur.
#
# ### Testing & Qualitätssicherung
#
# Tests validieren, dass Software funktioniert – funktional wie nicht-funktional. Neben Unit-Tests zählen auch:
#
# * Integrationstests
# * E2E-Tests
# * Performance-Tests
# * Security Audits
#
# 🚀 **Software Product Mastering Bezug:**
# Tests sind bei uns **nicht nachgelagert**, sondern integraler Bestandteil jeder Entwicklungsstufe. Wir praktizieren **Test First**, und lassen Tests als **Spezifikation** mitwirken. Automatisierung und Metriken sind Standard.
#
# ### Deployment & Betrieb
#
# Code allein bringt nichts, wenn er nicht stabil läuft. DevOps-Kultur bedeutet:
#
# * Automatisiertes Deployment
# * Monitoring & Logging
# * Fehlererkennung & -behandlung
#
# 🚀 **Software Product Mastering Bezug:**
# Wir denken in **Build-Measure-Learn-Zyklen**. Deployment ist kein Endpunkt, sondern der Anfang echter Produktinteraktion. Unsere Plattformen sind **observable**, **traceable** und auf schnelles Feedback ausgelegt.
#
# ### Feedback & Lernen
#
# Wie reagiert der Markt? Wie verhalten sich Nutzer\:innen? Welche Probleme treten auf? Produktentwicklung hört nie auf – Feedback ist zentral.
#
# 🚀 **Software Product Mastering Bezug:**
# Wir leben eine **Data Driven Culture** – mit Feature Flags, Telemetrie, Heatmaps, Post-Mortems und Hypothesen-getriebenem Arbeiten. Fehler sind Lernchancen – **Fehlerkultur ist kein Schlagwort**, sondern gelebter Alltag.
#
# ### Team & Kultur
#
# Selbst das beste Toolset nützt wenig, wenn das Team nicht funktioniert. Kultur, Rollenverständnis, Entscheidungsprozesse und Kommunikation prägen den Erfolg.
#
# 🚀 **Software Product Mastering Bezug:**
# Wir fördern **Autonomie**, **Mastery**, **Purpose** – orientiert an Daniel Pinks Prinzipien. Hierarchie tritt hinter **Verantwortung** zurück. Wir nutzen Retrospektiven, Development Talks, Rollenklärung, Mentoring – und gestalten Teams als lernende Systeme.
#
# ### Fazit
#
# **Programmieren ist essenziell – aber nie allein.**
# Im Softwareentwicklungsprozess geht es um mehr als Technik: Es geht um Verstehen, Gestalten, Liefern und Lernen.
#
# Mit **Software Product Mastering** entsteht ein Rahmen, in dem **Technologie**, **Praktiken** und **Kultur** zusammenwirken – für nachhaltige, nützliche und geliebte Produkte.
